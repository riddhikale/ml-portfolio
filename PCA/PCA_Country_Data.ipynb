# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Country-data.csv')
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
X = df.drop(columns=['country'])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(X_scaled)
# Out:
# PCA()

# %%
print("Variance explained by each component:", pca.explained_variance_ratio_)
print("Cumulative variance:", pca.explained_variance_ratio_.cumsum())
# Out:
# Variance explained by each component: [0.4595174  0.17181626 0.13004259 0.11053162 0.07340211 0.02484235
#  0.0126043  0.00981282 0.00743056]
# Cumulative variance: [0.4595174  0.63133365 0.76137624 0.87190786 0.94530998 0.97015232
#  0.98275663 0.99256944 1.        ]

# %%
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Variance Explained')
plt.title('PCA Scree Plot')
plt.axhline(y=0.9, color='r', linestyle='--', label='90% variance')
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans

pca_5 = PCA(n_components=5)
X_pca = pca_5.fit_transform(X_scaled)

# %%
print(f"Variance retained: {pca_5.explained_variance_ratio_.sum():.4f}")
# Out:
# Variance retained: 0.9453

# %%
kmeans_pca = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters_pca = kmeans_pca.fit_predict(X_pca)
