# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("House_Rent_Dataset.csv")
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
df.shape
# Out:
# (4746, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   str
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   str
#  5   Area Type          4746 non-null   str
#  6   Area Locality      4746 non-null   str
#  7   City               4746 non-null   str
#  8   Furnishing Status  4746 non-null   str
#  9   Tenant Preferred   4746 non-null   str
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   str
# dtypes: int64(4), str(8)
# memory usage: 887.8 KB

# %%
df.describe(include='all').T
# Out:
#                     count unique               top  freq          mean  \
# Posted On            4746     81        2022-07-06   311           NaN
# BHK                4746.0    NaN               NaN   NaN       2.08386
# Rent               4746.0    NaN               NaN   NaN  34993.451327
# Size               4746.0    NaN               NaN   NaN    967.490729
# Floor                4746    480        1 out of 2   379           NaN
# Area Type            4746      3        Super Area  2446           NaN
# Area Locality        4746   2235       Bandra West    37           NaN
# City                 4746      6            Mumbai   972           NaN
# Furnishing Status    4746      3    Semi-Furnished  2251           NaN
# Tenant Preferred     4746      3  Bachelors/Family  3444           NaN
# Bathroom           4746.0    NaN               NaN   NaN      1.965866
# Point of Contact     4746      3     Contact Owner  3216           NaN
#
#                             std     min      25%      50%      75%        max
# Posted On                   NaN     NaN      NaN      NaN      NaN        NaN
# BHK                    0.832256     1.0      2.0      2.0      3.0        6.0
# Rent               78106.412937  1200.0  10000.0  16000.0  33000.0  3500000.0
# Size                 634.202328    10.0    550.0    850.0   1200.0     8000.0
# Floor                       NaN     NaN      NaN      NaN      NaN        NaN
# Area Type                   NaN     NaN      NaN      NaN      NaN        NaN
# Area Locality               NaN     NaN      NaN      NaN      NaN        NaN
# City                        NaN     NaN      NaN      NaN      NaN        NaN
# Furnishing Status           NaN     NaN      NaN      NaN      NaN        NaN
# Tenant Preferred            NaN     NaN      NaN      NaN      NaN        NaN
# Bathroom               0.884532     1.0      1.0      2.0      2.0       10.0
# Point of Contact            NaN     NaN      NaN      NaN      NaN        NaN

# %%
df.columns.tolist()
# Out:
# ['Posted On',
#  'BHK',
#  'Rent',
#  'Size',
#  'Floor',
#  'Area Type',
#  'Area Locality',
#  'City',
#  'Furnishing Status',
#  'Tenant Preferred',
#  'Bathroom',
#  'Point of Contact']

# %%
df.drop(columns=['Posted On', 'Floor', 'Area Locality', 'Tenant Preferred', 'Point of Contact'], inplace=True)

# %%
print(df.isnull().sum())
# Out:
# BHK                  0
# Rent                 0
# Size                 0
# Area Type            0
# City                 0
# Furnishing Status    0
# Bathroom             0
# dtype: int64

# %%
# One hot encode categorical columns
df = pd.get_dummies(df, columns=['Area Type', 'City', 'Furnishing Status'], drop_first=True)

# %%
print(df.shape)
print(df.columns.tolist())
print(df.head())
# Out:
# (4746, 13)
# ['BHK', 'Rent', 'Size', 'Bathroom', 'Area Type_Carpet Area', 'Area Type_Super Area', 'City_Chennai', 'City_Delhi', 'City_Hyderabad', 'City_Kolkata', 'City_Mumbai', 'Furnishing Status_Semi-Furnished', 'Furnishing Status_Unfurnished']
#    BHK   Rent  Size  Bathroom  Area Type_Carpet Area  Area Type_Super Area  \
# 0    2  10000  1100         2                  False                  True
# 1    2  20000   800         1                  False                  True
# 2    2  17000  1000         1                  False                  True
# 3    2  10000   800         1                  False                  True
# 4    2   7500   850         1                   True                 False
#
#    City_Chennai  City_Delhi  City_Hyderabad  City_Kolkata  City_Mumbai  \
# 0         False       False           False          True        False
# 1         False       False           False          True        False
# 2         False       False           False          True        False
# 3         False       False           False          True        False
# 4         False       False           False          True        False
#
#    Furnishing Status_Semi-Furnished  Furnishing Status_Unfurnished
# 0                             False                           True
# 1                              True                          False
# 2                              True                          False
# 3                             False                           True
# 4                             False                           True
